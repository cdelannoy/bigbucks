# %%
import yfinance as yf
import pandas as pd
import os
import datetime
import pickle

# %%
# Some important functions
def save_obj(obj, name):
    with open('data/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open('data/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)
    
def getTickerDat(ticks):
tickerDat = {}
for t in ticks:
    print('{}% done'.format(round(100*(len(tickerDat)+1)/len(ticks)),6))
    stockDat = yf.download(t, 
                           start=insiderDat.TradeDate.min().strftime("%Y-%m-%d"), 
                           end=insiderDat.TradeDate.max().strftime("%Y-%m-%d"), 
                           progress=False)
    tickerDat[t] = stockDat
return tickerDat

# %%
insiderDat = pd.read_csv('data/openinsider_June.csv')

# %%
insiderDat = insiderDat.rename(columns={insiderDat.columns[1]: "FilingDate", 
                                        insiderDat.columns[2]: "TradeDate", 
                                        insiderDat.columns[4]: "CompanyName", 
                                        insiderDat.columns[5]: "InsiderName", 
                                        insiderDat.columns[7]: "TradeType",
                                        insiderDat.columns[11]: "DeltaOwn"},
                              errors="raise")
insiderDat.FilingDate = [datetime.datetime.strptime(r, '%m/%d/%y %H:%M') for r in insiderDat.FilingDate]
insiderDat.TradeDate = [datetime.datetime.strptime(r, '%m/%d/%y') for r in insiderDat.TradeDate]

insiderDat.head()
# Out:
#      X          FilingDate  TradeDate Ticker  \
# 0  NaN 2021-06-11 18:00:00 2021-06-11    IBP
# 1  NaN 2021-06-11 19:21:00 2021-06-11    DXC
# 2  NaN 2021-06-11 16:50:00 2021-06-11   REVG
# 3  NaN 2021-06-11 19:43:00 2021-06-11   AMST
# 4  NaN 2021-06-11 19:47:00 2021-06-11   TLYS
#
#                          CompanyName            InsiderName Title  \
# 0  Installed Building Products, Inc.       Thomas Michael H   Dir
# 1                  Dxc Technology Co       Fernandez Raul J   Dir
# 2                    Rev Group, Inc.  Boettinger Stephen W.    GC
# 3                       Amesite Inc.       Sastry Ann Marie   CEO
# 4                      Tilly'S, Inc.       Zeichner Bernard   Dir
#
#       TradeType     Price     Qty      Owned DeltaOwn       Value  1d  1w  1m  \
# 0      S - Sale  $116.85   -2,100     10,093     -17%  ($245,378) NaN NaN NaN
# 1  P - Purchase   $41.20    1,820     31,305       6%    $74,975  NaN NaN NaN
# 2  P - Purchase   $15.64    1,500    121,560       1%    $23,460  NaN NaN NaN
# 3  P - Purchase    $3.73   15,000  6,241,667       0%    $55,950  NaN NaN NaN
# 4      S - Sale   $16.24   -5,000     46,894     -10%   ($81,200) NaN NaN NaN
#
#    6m
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
allTickers = insiderDat.Ticker.unique()
len(allTickers)
# Out:
# 913

# %%
#historicDat = getTickerDat(allTickers[0:5])
#save_obj(historicDat, 'historicDat')
# Out:
# 20% done
# 40% done
# 60% done
# 80% done
# 100% done
